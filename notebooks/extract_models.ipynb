# %%
import os
import sys
from PIL import Image
import numpy as np
import time
import pandas as pd
import time
from pydrive.drive import GoogleDrive as gd


from google.colab import drive
drive.mount('/content/Gdrive', force_remount=True)
dir = "/content/Gdrive/My Drive/Colab Notebooks/PRE/Multi-Modalities/"
export_dir = "/content/Gdrive/My\ Drive/Colab\ Notebooks/PRE/Multi-Modalities/exports/"
data_dir = "/content/Gdrive/My Drive/Colab Notebooks/PRE/Data/"
#dir = "/Users/Alex2/Desktop/Multi Modalities/"
#data_dir = dir
sys.path.append(dir)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/Gdrive

# %%
training_files = os.listdir(dir + "Trainings/")
# vérifie si il y a le model epoch 100:
for training in training_files:
    path = dir + "Trainings/" + training + "/Pre_trained_model/" 
    model_file = path + training + "model_epoch_100.pth"
    if os.path.isfile(model_file):
        model_file = model_file.replace(" ", "\ ")
        model_file = model_file.replace(">", "\>")
        print("exporting ", model_file, " to the export directory: ", export_dir)
        # !cp $model_file $export_dir
# Out:
# exporting  /content/Gdrive/My\ Drive/Colab\ Notebooks/PRE/Multi-Modalities/Trainings/t1w-\>t1w\ 32blocs/Pre_trained_model/t1w-\>t1w\ 32blocsmodel_epoch_100.pth  to the export directory:  /content/Gdrive/My\ Drive/Colab\ Notebooks/PRE/Multi-Modalities/exports/
# exporting  /content/Gdrive/My\ Drive/Colab\ Notebooks/PRE/Multi-Modalities/Trainings/t1w_t2w-\>t1w\ 32blocs/Pre_trained_model/t1w_t2w-\>t1w\ 32blocsmodel_epoch_100.pth  to the export directory:  /content/Gdrive/My\ Drive/Colab\ Notebooks/PRE/Multi-Modalities/exports/
# exporting  /content/Gdrive/My\ Drive/Colab\ Notebooks/PRE/Multi-Modalities/Trainings/t1w_t1gd-\>t1w\ 32blocs/Pre_trained_model/t1w_t1gd-\>t1w\ 32blocsmodel_epoch_100.pth  to the export directory:  /content/Gdrive/My\ Drive/Colab\ Notebooks/PRE/Multi-Modalities/exports/
# ...
